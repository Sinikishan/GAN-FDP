# %% [markdown]
# I just made a GAN for cars from this dataset, cause I was bored. The dataset isn't meant for it, But I did it anyways :D
# <br>
# Code uses pytorch for making a GAN

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05938.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06122.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04168.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02371.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04377.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00767.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07457.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02360.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05222.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03999.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00266.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02450.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01496.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01600.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05248.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03508.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00847.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06957.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00822.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00614.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02856.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02621.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01850.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07015.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00878.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/08020.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05183.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01473.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03913.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03037.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00091.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06572.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01713.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06857.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01306.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00838.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01760.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05320.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04211.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03197.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02600.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00296.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04848.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04404.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01000.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01445.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01179.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06978.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02179.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07329.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07448.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05383.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04896.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05877.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00219.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06922.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02567.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05754.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03929.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02327.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07618.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07946.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06431.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05841.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03088.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02817.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05225.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04729.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01029.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04441.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07196.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00130.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04776.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00460.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07882.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04017.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04506.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00254.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07587.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07405.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00884.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02585.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03069.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06563.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01329.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00706.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00896.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04456.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03603.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00160.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06712.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06909.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02085.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01173.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04753.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00109.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04772.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07419.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02787.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04249.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04757.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02880.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06489.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05437.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04611.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07319.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02696.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00111.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04991.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07089.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05929.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01081.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02997.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/08033.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04413.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04153.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05523.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05679.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01779.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01728.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06034.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04039.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05465.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02418.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05269.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03954.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00056.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05353.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04380.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04096.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06806.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02308.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02392.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01978.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03003.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02238.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01093.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04462.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04472.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07768.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06991.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06900.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07541.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02686.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07757.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03166.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06825.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01307.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02774.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00030.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06526.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01133.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00907.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02099.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04144.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03447.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01616.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07894.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07849.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04054.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05981.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00944.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01045.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04188.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02201.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05579.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07436.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07643.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07134.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01980.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03355.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00942.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07382.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07304.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05782.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03897.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07895.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03585.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00680.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03425.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06793.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04586.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07149.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02432.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06075.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01864.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01683.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00938.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01643.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02670.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05533.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02191.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00571.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05430.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06210.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01535.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03362.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07737.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04567.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07924.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00808.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05558.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07853.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03149.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04525.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03011.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05821.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01809.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00340.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07251.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02313.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01017.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04690.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02809.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00074.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03154.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02310.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00009.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06418.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00530.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07380.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03737.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03042.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03034.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00361.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02611.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01194.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05395.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01921.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05680.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01487.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06942.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01886.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01406.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01151.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02266.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04775.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06663.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00308.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07918.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03231.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05855.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05379.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03311.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01071.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03869.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02757.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01001.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02119.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01547.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02984.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02457.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00580.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06442.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02212.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04271.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04006.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05978.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00439.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07942.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06311.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01458.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02118.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04615.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03120.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00161.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05524.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03180.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02605.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07101.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03177.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03782.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02541.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06869.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00377.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03729.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01137.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01861.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03065.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01888.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04688.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03689.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03369.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04074.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07496.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02367.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07181.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04902.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01149.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07006.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04660.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01672.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06816.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05315.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01727.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00802.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05038.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06056.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05890.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03254.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04322.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05163.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05964.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07640.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07996.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06290.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04482.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04518.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07423.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04636.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04429.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07997.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04884.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00215.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06684.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02639.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04252.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07312.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00116.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05701.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07004.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01420.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03384.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04930.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02048.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00681.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01906.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06082.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05707.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06383.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00081.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00280.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03587.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03395.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06192.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07198.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04040.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01963.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06387.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06084.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02783.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00428.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01067.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04298.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05613.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01212.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01777.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02349.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02066.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06616.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01139.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06090.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00468.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00324.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02775.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04598.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01862.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03673.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01569.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04504.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00976.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06946.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06235.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06918.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07813.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03842.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03497.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04618.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07703.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00694.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03271.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06437.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04910.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00596.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03173.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03882.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00787.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02714.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06064.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07464.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01718.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04427.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02325.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05381.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02914.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00879.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02724.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/08029.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06300.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00316.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07564.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03446.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00269.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00364.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01662.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07426.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00299.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07332.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02094.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06024.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03153.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06956.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07675.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02184.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02673.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07349.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01596.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00754.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00983.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04051.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01901.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06568.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05618.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06513.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00872.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05835.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07892.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04916.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07728.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04724.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03402.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07727.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03512.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02278.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02279.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06232.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02209.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00743.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03736.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06974.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02396.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04029.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04431.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01413.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03858.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07407.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05201.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00560.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04218.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05561.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04656.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02897.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07576.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05743.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02814.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03619.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05639.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00386.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06250.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04538.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01215.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00498.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00581.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01123.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03837.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05429.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06982.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07987.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06141.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05176.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02270.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02168.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01068.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03076.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07465.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02205.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03345.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03004.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06233.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04788.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03481.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05362.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05799.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02954.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06781.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01118.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04234.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06257.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02281.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06717.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00629.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05948.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07043.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07790.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06478.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06623.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00795.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05615.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04241.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04767.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03574.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03761.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05745.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00995.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06452.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01410.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04296.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00784.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04838.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06324.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03079.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04709.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04664.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04046.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03884.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00785.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01847.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07828.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05724.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/08015.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05013.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07135.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05094.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07555.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01250.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05148.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05831.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02470.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06894.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05525.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05050.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01284.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07759.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00516.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01065.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03796.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05555.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03195.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07127.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04088.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06025.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02761.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01387.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06640.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/08032.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06453.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01876.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00936.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02163.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05543.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02837.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03448.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05393.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05042.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01336.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07641.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01274.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01678.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06227.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02949.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07132.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04895.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05356.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04207.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05818.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03665.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05798.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00363.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01340.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07176.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01283.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07272.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00950.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01738.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03470.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04500.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01094.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07325.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04762.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02291.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07439.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07656.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01097.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02618.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01155.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04432.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07412.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00413.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03290.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03591.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05510.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05301.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04774.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02715.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06153.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02900.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00893.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05454.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06020.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01131.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02226.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04083.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04449.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03925.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07194.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04493.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01175.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07510.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04412.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03758.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01415.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00237.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04832.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00381.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01646.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03671.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04042.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07460.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05169.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01614.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03627.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02864.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00617.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04733.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06281.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07023.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05174.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05593.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07016.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04095.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07441.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06551.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06631.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05499.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04715.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02750.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05846.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07301.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05284.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07692.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05406.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03956.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02675.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06583.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01996.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03326.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07930.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00359.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06030.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04082.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01971.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04960.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07814.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01992.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06757.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06495.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01964.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01156.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01374.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05138.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03969.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06905.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04169.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04845.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04802.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06919.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01908.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06152.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03096.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00411.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02848.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06755.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05570.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03163.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01354.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07665.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00023.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04823.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04193.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03549.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05540.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07769.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01815.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02336.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04190.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03602.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01894.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06809.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00873.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04975.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01597.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01172.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06408.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03700.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00887.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00387.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01234.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01953.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00678.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00380.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04342.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07245.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02240.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01947.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00107.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03881.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02957.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01136.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06710.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00357.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03569.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06501.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01747.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/01823.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06201.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02260.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05512.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00549.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06443.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00624.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04553.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00798.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/04888.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02089.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02206.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/07838.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00511.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05432.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06483.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05337.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05323.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/00816.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/05721.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03573.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/06325.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/02933.jpg
# /kaggle/input/stanford-cars-dataset/cars_test/cars_test/03403.jpg
# ...
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/06627.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/06360.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/03492.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/04280.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/05723.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/05965.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/04244.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/05416.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/06633.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/00032.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/06147.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/02584.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/02523.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/08093.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/06369.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/04822.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/05211.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/05653.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/03638.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/03308.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/06908.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/00313.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/07999.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/01220.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/07378.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/07485.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/04817.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/05496.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/01504.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/02873.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/03550.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/06798.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/08077.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/03091.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/04973.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/03588.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/05399.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/04648.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/07234.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/00232.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/04300.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/05562.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/06223.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/00616.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/02564.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/04038.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/05385.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/07809.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/01472.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/02188.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/05633.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/03262.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/06601.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/00980.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/04292.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/02500.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/07959.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/07725.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/03179.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/03123.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/08097.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/04316.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/06184.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/02448.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/01765.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/04411.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/00606.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/05371.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/01477.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/03344.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/06651.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/06395.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/05621.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/04929.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/02820.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/03109.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/07416.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/04540.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/04365.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/05422.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/00845.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/06061.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/01776.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/06770.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/01289.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/07560.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/01770.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/05514.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/04221.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/04856.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/02213.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/01141.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/01763.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/05637.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/02922.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/00590.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/07599.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/07652.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/04055.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/03620.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/01373.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/04691.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/05434.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/05024.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/06146.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/02333.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/01185.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/05224.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/03721.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/07143.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/02807.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/02083.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/08041.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/03225.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/01564.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/02390.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/05885.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/01025.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/04182.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/02106.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/02491.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/04932.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/06471.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/00691.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/02834.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/06426.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/04653.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/04913.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/00659.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/01552.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/01222.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/02998.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/06700.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/04542.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/04565.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/00180.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/02242.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/01923.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/01810.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/05375.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/05191.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/07943.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/07229.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/07434.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/00458.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/02668.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/02109.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/06049.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/06753.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/00533.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/03688.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/02273.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/06357.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/06609.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/04121.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/06316.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/05253.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/00304.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/03328.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/07839.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/02959.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/04505.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/03957.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/00096.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/01057.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/02764.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/04109.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/00112.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/05328.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/07874.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/07978.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/07508.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/07974.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/08023.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/07478.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/02599.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/06511.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/04966.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/04707.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/07459.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/05946.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/06018.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/07085.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/04725.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/01580.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/02831.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/07185.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/03874.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/03129.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/06880.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/06261.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/02765.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/04282.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/00264.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/05536.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/06460.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/03277.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/04138.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/03728.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/00040.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/07667.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/00986.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/03080.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/06537.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/05436.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/05237.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/06206.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/00018.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/00319.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/06197.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/05408.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/01863.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/02784.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/04535.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/02731.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/08009.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/05727.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/03617.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/06575.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/07760.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/01325.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/06891.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/00222.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/02956.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/06983.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/06345.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/04731.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/03358.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/04801.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/06465.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/05601.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/05814.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/05859.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/05983.jpg
# /kaggle/input/stanford-cars-dataset/cars_train/cars_train/00117.jpg

# %% [markdown]
# # Importing The Right Modules
# just the importing stuff, if you're familiar with torch, you'll know what these are for

# %%
import torch
import torchvision
from torchvision.datasets import ImageFolder
import torch.nn as nn
import torchvision.transforms as tt
import torch.nn.functional as F
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
# %matplotlib inline
from torchvision.utils import save_image
from torchvision.utils import make_grid
from tqdm.notebook import tqdm

# %% [markdown]
# # Getting our Data Ready
# here we define our, path, image size, batch size and normalization stats for getting our data ready for processing

# %%
data_path = "../input/stanford-cars-dataset/cars_train"
image_size = 256
batch_size = 64
normstats = (0.,0.,0.),(1.,1.,1.)
transforms = tt.Compose([tt.Resize(image_size),#resize to make things uniform
                        tt.CenterCrop(image_size),#cropping to the center to avoid distortion
                        tt.ToTensor(),#to a tensor
                        tt.Normalize(*normstats)#normalizing in order to increase effectiveness of our GAN
                        ])
dataset = ImageFolder(data_path, transform = transforms)
img, _ = dataset[0]
plt.imshow(img.permute((1,2,0)))

# %%
def denorm(img_tensors):
    return img_tensors * normstats[1][0] + normstats[0][0]

def show_batch(dl):#just to show one batch of our data
    for img, _ in dl:
        fig, ax = plt.subplots(figsize=(8,8))
        ax.set_xticks([]);ax.set_yticks([])
        ax.imshow(torchvision.utils.make_grid(img[:64],nrow = 8).permute(1,2,0))
        break

def show_images(images):
    fig, ax = plt.subplots(figsize=(8,8))
    ax.set_xticks([]),ax.set_yticks([])
    ax.imshow(torchvision.utils.make_grid(denorm(images.detach()[:64]),nrow = 8).permute(1,2,0))

dataload = DataLoader(dataset,batch_size,num_workers = 4,shuffle = True, pin_memory=True)#makes our data into batches
show_batch(dataload)

# %% [markdown]
# # GPU Time!
# here we define classes that load stuff to our accelerator that would help us achieve faster epochs

# %%
def find_default_device():
    if torch.cuda.is_available():
        return torch.device("cuda")
    else:
        return torch.device('cpu')

# %%
device = find_default_device()

# %%
device
# Out:
# device(type='cuda')

# %%
def to_device(data,device):
    if isinstance(data,(list,tuple)):
        return [to_device(x,device) for x in data]
    else:
        return data.to(device, non_blocking=True)

# %%
class DataloaderDeviced():
    def __init__(self,data,device):
        self.data = data
        self.device = device
    def __iter__(self):
        for b in self.data:
            yield to_device(b,self.device)
    def __len__(self):
        return len(self.data)

# %%
dataload = DataloaderDeviced(dataload,device)

# %% [markdown]
# # Making our Discirminator
# we have input images of size 3x256x256
# we are now trying to define a discriminator network that would differentiate between fake and real images acting as the loss function to our generator.
# <br>essentially:
# <br>this guy is the guy who tells our generator how wrong his generated image is, based off which changes to the generated images are made

# %%
descriminator = nn.Sequential(
    #input size being of 3 channels, 256x256
    nn.Conv2d(3, 32 ,kernel_size = 3, stride = 2, padding = 1, bias = False),
    nn.BatchNorm2d(32),
    nn.LeakyReLU(0.1, inplace=True),
    #output size being of 32 channels, 128x128

    nn.Conv2d(32,64,kernel_size = 4, stride = 2, padding = 1, bias = False),
    nn.BatchNorm2d(64),
    nn.LeakyReLU(0.1, inplace=True),
    #out 64x64x64

    nn.Conv2d(64,128,kernel_size = 4, stride = 2, padding = 1, bias = False),
    nn.BatchNorm2d(128),
    nn.LeakyReLU(0.1, inplace = True),
    #out 128x32x32

    nn.Conv2d(128,256,kernel_size = 4, stride = 2, padding = 1, bias = False),
    nn.BatchNorm2d(256),
    nn.LeakyReLU(0.1,inplace = True),
    #out 256x16x16

    nn.Conv2d(256,512, kernel_size = 4, stride = 2, padding = 1, bias = False),
    nn.BatchNorm2d(512),
    nn.LeakyReLU(0.1, inplace = True),
    #out 512x8x8

    nn.Conv2d(512,1024, kernel_size = 4, stride = 2, padding = 1, bias = False),
    nn.BatchNorm2d(1024),
    nn.LeakyReLU(0.1,inplace = True),
    #out 1024x4x4

    nn.Conv2d(1024,1,kernel_size = 4,stride = 1, padding = 0, bias = False),
    #out 1x1x1

    nn.Flatten(),
    nn.Sigmoid(),
    #final activation for T/F
)

#descriminator.load_state_dict(torch.load("../input/weights/discweights4.pth"))
descriminator = to_device(descriminator,device)
descriminator
# Out:
# Sequential(
#   (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.1, inplace=True)
#   (3): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (5): LeakyReLU(negative_slope=0.1, inplace=True)
#   (6): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (7): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): LeakyReLU(negative_slope=0.1, inplace=True)
#   (9): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (10): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (11): LeakyReLU(negative_slope=0.1, inplace=True)
#   (12): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (13): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (14): LeakyReLU(negative_slope=0.1, inplace=True)
#   (15): Conv2d(512, 1024, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (16): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (17): LeakyReLU(negative_slope=0.1, inplace=True)
#   (18): Conv2d(1024, 1, kernel_size=(4, 4), stride=(1, 1), bias=False)
#   (19): Flatten()
#   (20): Sigmoid()
# )

# %% [markdown]
# # Making our Generator
# taking in a latent vector of size 128, we're going to generate an image of size 256x256.<br>
# this is our generator, here, we take in a random tensor(a random value for imagining our random image), and then by the magic of transposed convolutions, we generate images.

# %%
latent_sz = 128

# %%
generator = nn.Sequential(
    #latent in 128x1x1
    nn.ConvTranspose2d(128,1024,kernel_size = 4, stride = 1, padding = 0, bias = False),
    nn.BatchNorm2d(1024),
    nn.LeakyReLU(0.1, inplace=True),
    #out 1024x4x4

    nn.ConvTranspose2d(1024,512,kernel_size = 4, stride = 2, padding = 1, bias = False),
    nn.BatchNorm2d(512),
    nn.LeakyReLU(0.1, inplace=True),
    #out 512x8x8

    nn.ConvTranspose2d(512,256,kernel_size = 4, stride = 2, padding = 1, bias = False),
    nn.BatchNorm2d(256),
    nn.LeakyReLU(0.1, inplace=True),
    #out 256x16x16

    nn.ConvTranspose2d(256,128,kernel_size = 4, stride = 2, padding = 1, bias = False),
    nn.BatchNorm2d(128),
    nn.LeakyReLU(0.1, inplace=True),
    #out 128x32x32

    nn.ConvTranspose2d(128,64,kernel_size = 4, stride = 2, padding = 1, bias = False),
    nn.BatchNorm2d(64),
    nn.LeakyReLU(0.1, inplace=True),
    #out 64x64x64

    nn.ConvTranspose2d(64,32,kernel_size = 4, stride = 2, padding = 1, bias = False),
    nn.BatchNorm2d(32),
    nn.LeakyReLU(0.1, inplace=True),
    #out 32x128x128

    nn.ConvTranspose2d(32,3,kernel_size = 4, stride = 2, padding = 1, bias = False),
    nn.Tanh()
    #out 3x256x256

)
#generator.load_state_dict(torch.load("../input/weights/genweights4.pth"))
generator
# Out:
# Sequential(
#   (0): ConvTranspose2d(128, 1024, kernel_size=(4, 4), stride=(1, 1), bias=False)
#   (1): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (2): LeakyReLU(negative_slope=0.1, inplace=True)
#   (3): ConvTranspose2d(1024, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (5): LeakyReLU(negative_slope=0.1, inplace=True)
#   (6): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (7): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (8): LeakyReLU(negative_slope=0.1, inplace=True)
#   (9): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (10): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (11): LeakyReLU(negative_slope=0.1, inplace=True)
#   (12): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (13): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (14): LeakyReLU(negative_slope=0.1, inplace=True)
#   (15): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (16): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (17): LeakyReLU(negative_slope=0.1, inplace=True)
#   (18): ConvTranspose2d(32, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   (19): Tanh()
# )

# %%
xb = torch.randn(batch_size,latent_sz,1,1,)
fake_images = generator(xb)
show_images(fake_images)
generator = to_device(generator,device)

# %% [markdown]
# # Training functions
# ### training our discriminator
# Here's how we train a GAN, we first feed real images form our dataset to the discriminator(whose job is basically to tell if the generated image is fake or real),<br>
# Ideally for images from our dataset, our discrimiator should return 'real'(1), so our target is sessentially 1<br>
# <br>
# We also generate fake images from our generator so that our discriminator knows what a 'fake' image is aswell, so here, our target is 'fake'(0).
# <br>
# Based off the outputs we recive, we backpropogate and updates the weights accordingly to recive the ideal outputs.

# %%
def train_discriminator(real_images,opt_d):

    opt_d.zero_grad()
    real_preds = descriminator(real_images)
    real_targets = torch.ones(real_images.size(0),1,device = device)
    real_loss = F.binary_cross_entropy(real_preds,real_targets)
    real_score = torch.mean(real_preds).item()

    latent = torch.randn(batch_size,latent_sz,1,1, device = device)
    fake_images = generator(latent)

    fake_preds = descriminator(fake_images)
    fake_targets = torch.zeros(fake_images.size(0),1,device = device)
    fake_loss = F.binary_cross_entropy(fake_preds,fake_targets)
    fake_score = torch.mean(fake_preds).item()

    loss = fake_loss+real_loss
    loss.backward()
    opt_d.step()

    return loss.item(),real_score,fake_score

# %% [markdown]
# ### training our generator
# So we know that, given an input random tensor we recive an image from our generator, so we essentially generate a batch of images from our generator and give them to the discriminator, who then returns 1 or 0 depending if the image is real or not, Ideally we ****should**** be able to fool our discirminator, so the fake images we generate should return a value of 1(real).
# <br>
# based off what our discriminator returns, we then backpropogate and update the weights accordingly.

# %%
def train_generator(opt_g):
    opt_g.zero_grad()
    latent = torch.randn(batch_size,latent_sz, 1,1, device = device)
    images = generator(latent)

    targets = torch.ones(batch_size,1,device = device)
    score = descriminator(images)
    loss = F.binary_cross_entropy(score,targets)

    loss.backward()
    opt_g.step()

    return loss.item()

# %% [markdown]
# # Helper Functions to Save images
#
# here we have helper functions that help us save images we generated in each training epoch

# %%
savedir = "gen"
os.makedirs(savedir, exist_ok = True)

# %%
def save_samples(index, latent_tensors, show=True):
    fake_images = generator(latent_tensors)
    fake_fname = 'generated-images-{0:0=4d}e1.png'.format(index+90)
    save_image(denorm(fake_images), os.path.join(savedir, fake_fname), nrow=8)
    print('Saving', fake_fname)
    if show:
        fig, ax = plt.subplots(figsize=(8, 8))
        ax.set_xticks([]); ax.set_yticks([])
        ax.imshow(make_grid(fake_images.cpu().detach(), nrow=8).permute(1, 2, 0))

# %%
torch.manual_seed(64)
fixed_latent = torch.randn(batch_size, latent_sz, 1, 1, device=device)

# %%
save_samples(0,fixed_latent)
# Out:
# Saving generated-images-0090e1.png

# %% [markdown]
# # The Fit function
# here we fit our images to the training dataset.

# %%
def fit(epochs, lr, start_idx = 1):
    loss_d =[]
    loss_g = []
    real_scores = []
    fake_scores = []

    opt_d = torch.optim.Adam(descriminator.parameters(), lr=lr, betas=(0.5, 0.999))
    opt_g = torch.optim.Adam(generator.parameters(), lr=lr, betas=(0.5, 0.999))

    for epoch in range(epochs):
        for img, _ in tqdm(dataload):

            loss, real_score, fake_score = train_discriminator(img, opt_d)
            lossg = train_generator(opt_g)

        loss_d.append(loss)
        loss_g.append(lossg)
        real_scores.append(real_score)
        fake_scores.append(fake_score)

        print("Epoch [{}/{}], loss_g: {:.4f}, loss_d: {:.4f}, real_score: {:.4f}, fake_score: {:.4f}".format(
            epoch+1, epochs, loss, lossg, real_score, fake_score))

        save_samples(epoch+start_idx, fixed_latent, show=False)

    return loss_g,loss_d,real_scores,fake_scores

# %%
lr = 5e-4
epochs = 2
history = fit(epochs,lr)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=128.0), HTML(value='')))
# Epoch [1/2], loss_g: 0.0163, loss_d: 6.6807, real_score: 0.9875, fake_score: 0.0036
# Saving generated-images-0091e1.png
# HBox(children=(FloatProgress(value=0.0, max=128.0), HTML(value='')))
# Epoch [2/2], loss_g: 0.0283, loss_d: 5.0004, real_score: 0.9973, fake_score: 0.0252
# Saving generated-images-0092e1.png

# %% [markdown]
# # Saving our Weights
# Yeah kaggle disconnects interactive sessions after a while,so we save and download the weights to see how the progress goes for the number of epochs we ran
# <br>
# we save the weights into .pth files

# %%
torch.save(generator.state_dict(),"genweights4.pth")

# %%
torch.save(descriminator.state_dict(),"discweights4.pth")

# %% [markdown]
# # Testing Our function
# we generate a single image and then display it.
# <br>
# we can inspect it ourselves to see how real this image can get

# %%
torch.manual_seed(94)
latent_test = torch.randn(1,latent_sz,1,1,device=device)
image = generator(latent_test)

# %%
image=to_device(image, torch.device("cpu"))
b=image[0].permute(1,2,0).detach().numpy()
b.shape
# Out:
# (256, 256, 3)

# %%
plt.imshow(b)

# %%
# !pip install jovian
# Out:
# Collecting jovian
#   Downloading jovian-0.2.47-py2.py3-none-any.whl (68 kB)
#      |████████████████████████████████| 68 kB 3.6 MB/s eta 0:00:011
# Collecting uuid
#   Downloading uuid-1.30.tar.gz (5.8 kB)
# Requirement already satisfied: requests in /opt/conda/lib/python3.7/site-packages (from jovian) (2.23.0)
# Requirement already satisfied: click in /opt/conda/lib/python3.7/site-packages (from jovian) (7.1.1)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.7/site-packages (from jovian) (5.3.1)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.7/site-packages (from requests->jovian) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.7/site-packages (from requests->jovian) (2020.4.5.2)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/lib/python3.7/site-packages (from requests->jovian) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/lib/python3.7/site-packages (from requests->jovian) (1.24.3)
# Building wheels for collected packages: uuid
#   Building wheel for uuid (setup.py) ... done
#   Created wheel for uuid: filename=uuid-1.30-py3-none-any.whl size=6500 sha256=235eedb6a9934df899e51fe3a36208d73c8257c026906484d30da17ac0889f47
#   Stored in directory: /root/.cache/pip/wheels/2a/ea/87/dd57f1ecb4f0752f3e1dbf958ebf8b36d920d190425bcdc24d
# Successfully built uuid
# Installing collected packages: uuid, jovian
# Successfully installed jovian-0.2.47 uuid-1.30
# WARNING: You are using pip version 20.1.1; however, version 23.1.2 is available.
# You should consider upgrading via the '/opt/conda/bin/python3.7 -m pip install --upgrade pip' command.

# %%
prjname="cars_generator"

# %%
import jovian

# %%
jovian.commit(project=prjname,environment = None)

# %% [markdown]
# # That's it
# Hope this experiment was informative and we could gain a few insights on how this dataset would work on our GAN
